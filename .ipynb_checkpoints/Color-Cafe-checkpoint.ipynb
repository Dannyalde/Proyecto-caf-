# %%
import source as sc
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
path="cafe.jpg"

img = sc.read_img(path)
img_normal,ref_white,mean,sample = sc.Normal(img,white_limit=220)

print(mean)

plt.figure(figsize=(10,8))

plt.subplot(1,2,1)
plt.imshow(ref_white)
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(img_normal)
plt.axis('off')

plt.show()
# Out:
# [253.67868779 253.43055471 253.49266387]

# %%
Lab_unfold = sc.RGB2Lab(img_normal.reshape(-1,3))
Lch_unfold = sc.Lab2Lch(Lab_unfold)

Lab = Lab_unfold.reshape(img_normal.shape)
Lch = Lch_unfold.reshape(img_normal.shape)

plt.figure(figsize=(15,10))

plt.subplot(1,3,1)
plt.imshow(Lab[:,:,0])
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(Lab[:,:,1])
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(Lab[:,:,2])
plt.axis('off')

plt.show()


plt.figure(figsize=(15,10))

plt.subplot(1,3,1)
plt.imshow(Lch[:,:,0])
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(Lch[:,:,1])
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(Lch[:,:,2])
plt.axis('off')

plt.show()

# %%
# MASCARA PARA VERDE
MaskL_Verde,img_maskL_Verde = sc.MaskLab(Lab,img_normal,"L",(50,80))
Maska_verde,img_maska_Verde = sc.MaskLab(MaskL_Verde,img_maskL_Verde,"a",(-30,10))

# MASCARA PARA PINTON
MaskL_Pinton,img_maskL_Pinton = sc.MaskLab(Lab,img_normal,"L",(32,83))
Maska_Pinton,img_maska_Pinton = sc.MaskLab(MaskL_Pinton,img_maskL_Pinton,"a",(-10,43))

# MASCARA PARA MADURO
MaskL_Maduro,img_maskL_Maduro = sc.MaskLab(Lab,img_normal,"L",(31,60))
Maska_Maduro,img_maska_Maduro = sc.MaskLab(MaskL_Maduro,img_maskL_Maduro,"a",(26,50))

# MASCARA PARA SOBREMADURO
MaskL_SMaduro,img_maskL_SMaduro = sc.MaskLab(Lab,img_normal,"L",(22,66))
Maska_SMaduro,img_maska_SMaudro = sc.MaskLab(MaskL_SMaduro,img_maskL_SMaduro,"a",(0,19))

# %%
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.title(str((Maska_verde[:,:,0][Maska_verde[:,:,0]!=0].shape[0]/sample)*100))
plt.imshow(img_maska_Verde)
plt.axis('off')

plt.subplot(2,2,2)
plt.title(str((Maska_Pinton[:,:,0][Maska_Pinton[:,:,0]!=0].shape[0]/sample)*100))
plt.imshow(img_maska_Pinton)
plt.axis('off')

plt.subplot(2,2,3)
plt.title(str((Maska_Maduro[:,:,0][Maska_Maduro[:,:,0]!=0].shape[0]/sample)*100))
plt.imshow(img_maska_Maduro)
plt.axis('off')

plt.subplot(2,2,4)
plt.title(str((Maska_SMaduro[:,:,0][Maska_SMaduro[:,:,0]!=0].shape[0]/sample)*100))
plt.imshow(img_maska_SMaudro)
plt.axis('off')


plt.show()
